# %%
! pip uninstall -y evidently
# Out:
# Found existing installation: evidently 0.7.7
# Uninstalling evidently-0.7.7:
#   Successfully uninstalled evidently-0.7.7

# %%
! pip install evidently==0.7.7
# Out:
# Collecting evidently==0.7.7
#   Using cached evidently-0.7.7-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: plotly<6,>=5.10.0 in .\venv\lib\site-packages (from evidently==0.7.7) (5.24.1)
# Requirement already satisfied: statsmodels>=0.12.2 in .\venv\lib\site-packages (from evidently==0.7.7) (0.14.4)
# Requirement already satisfied: scikit-learn>=1.0.1 in .\venv\lib\site-packages (from evidently==0.7.7) (1.6.1)
# Requirement already satisfied: pandas>=1.3.5 in .\venv\lib\site-packages (from pandas[parquet]>=1.3.5->evidently==0.7.7) (2.3.0)
# Requirement already satisfied: numpy>=1.22.0 in .\venv\lib\site-packages (from evidently==0.7.7) (2.0.2)
# Requirement already satisfied: nltk>=3.6.7 in .\venv\lib\site-packages (from evidently==0.7.7) (3.9.1)
# Requirement already satisfied: scipy>=1.10.0 in .\venv\lib\site-packages (from evidently==0.7.7) (1.13.1)
# Requirement already satisfied: requests>=2.32.0 in .\venv\lib\site-packages (from evidently==0.7.7) (2.32.4)
# Requirement already satisfied: PyYAML>=5.4 in .\venv\lib\site-packages (from evidently==0.7.7) (6.0.2)
# Requirement already satisfied: pydantic>=1.10.16 in .\venv\lib\site-packages (from evidently==0.7.7) (2.11.5)
# Requirement already satisfied: litestar>=2.8.3 in .\venv\lib\site-packages (from evidently==0.7.7) (2.16.0)
# Requirement already satisfied: typing-inspect>=0.9.0 in .\venv\lib\site-packages (from evidently==0.7.7) (0.9.0)
# Requirement already satisfied: uvicorn>=0.22.0 in .\venv\lib\site-packages (from uvicorn[standard]>=0.22.0->evidently==0.7.7) (0.34.3)
# Requirement already satisfied: watchdog>=3.0.0 in .\venv\lib\site-packages (from evidently==0.7.7) (6.0.0)
# Requirement already satisfied: typer>=0.3 in .\venv\lib\site-packages (from evidently==0.7.7) (0.16.0)
# Requirement already satisfied: rich>=13 in .\venv\lib\site-packages (from evidently==0.7.7) (14.0.0)
# Requirement already satisfied: iterative-telemetry>=0.0.5 in .\venv\lib\site-packages (from evidently==0.7.7) (0.0.10)
# Requirement already satisfied: dynaconf>=3.2.4 in .\venv\lib\site-packages (from evidently==0.7.7) (3.2.11)
# Requirement already satisfied: certifi>=2024.7.4 in .\venv\lib\site-packages (from evidently==0.7.7) (2025.4.26)
# Requirement already satisfied: urllib3>=1.26.19 in .\venv\lib\site-packages (from evidently==0.7.7) (2.4.0)
# Requirement already satisfied: fsspec>=2024.6.1 in .\venv\lib\site-packages (from evidently==0.7.7) (2025.5.1)
# Requirement already satisfied: ujson>=5.4.0 in .\venv\lib\site-packages (from evidently==0.7.7) (5.10.0)
# Requirement already satisfied: deprecation>=2.1.0 in .\venv\lib\site-packages (from evidently==0.7.7) (2.1.0)
# Requirement already satisfied: uuid6>=2024.7.10 in .\venv\lib\site-packages (from evidently==0.7.7) (2024.7.10)
# Requirement already satisfied: cryptography>=43.0.1 in .\venv\lib\site-packages (from evidently==0.7.7) (45.0.3)
# Requirement already satisfied: tenacity>=6.2.0 in .\venv\lib\site-packages (from plotly<6,>=5.10.0->evidently==0.7.7) (9.1.2)
# Requirement already satisfied: packaging in .\venv\lib\site-packages (from plotly<6,>=5.10.0->evidently==0.7.7) (25.0)
# Requirement already satisfied: cffi>=1.14 in .\venv\lib\site-packages (from cryptography>=43.0.1->evidently==0.7.7) (1.17.1)
# Requirement already satisfied: pycparser in .\venv\lib\site-packages (from cffi>=1.14->cryptography>=43.0.1->evidently==0.7.7) (2.22)
# Requirement already satisfied: appdirs in .\venv\lib\site-packages (from iterative-telemetry>=0.0.5->evidently==0.7.7) (1.4.4)
# Requirement already satisfied: filelock in .\venv\lib\site-packages (from iterative-telemetry>=0.0.5->evidently==0.7.7) (3.18.0)
# Requirement already satisfied: distro in .\venv\lib\site-packages (from iterative-telemetry>=0.0.5->evidently==0.7.7) (1.9.0)
# Requirement already satisfied: anyio>=3 in .\venv\lib\site-packages (from litestar>=2.8.3->evidently==0.7.7) (4.9.0)
# Requirement already satisfied: click in .\venv\lib\site-packages (from litestar>=2.8.3->evidently==0.7.7) (8.1.8)
# Requirement already satisfied: exceptiongroup in .\venv\lib\site-packages (from litestar>=2.8.3->evidently==0.7.7) (1.3.0)
# Requirement already satisfied: httpx>=0.22 in .\venv\lib\site-packages (from litestar>=2.8.3->evidently==0.7.7) (0.28.1)
# Requirement already satisfied: importlib-metadata in .\venv\lib\site-packages (from litestar>=2.8.3->evidently==0.7.7) (8.7.0)
# Requirement already satisfied: litestar-htmx>=0.4.0 in .\venv\lib\site-packages (from litestar>=2.8.3->evidently==0.7.7) (0.5.0)
# Requirement already satisfied: msgspec>=0.18.2 in .\venv\lib\site-packages (from litestar>=2.8.3->evidently==0.7.7) (0.19.0)
# Requirement already satisfied: multidict>=6.0.2 in .\venv\lib\site-packages (from litestar>=2.8.3->evidently==0.7.7) (6.4.4)
# Requirement already satisfied: multipart>=1.2.0 in .\venv\lib\site-packages (from litestar>=2.8.3->evidently==0.7.7) (1.2.1)
# Requirement already satisfied: polyfactory>=2.6.3 in .\venv\lib\site-packages (from litestar>=2.8.3->evidently==0.7.7) (2.21.0)
# Requirement already satisfied: rich-click in .\venv\lib\site-packages (from litestar>=2.8.3->evidently==0.7.7) (1.8.9)
# Requirement already satisfied: typing-extensions in .\venv\lib\site-packages (from litestar>=2.8.3->evidently==0.7.7) (4.14.0)
# Requirement already satisfied: idna>=2.8 in .\venv\lib\site-packages (from anyio>=3->litestar>=2.8.3->evidently==0.7.7) (3.10)
# Requirement already satisfied: sniffio>=1.1 in .\venv\lib\site-packages (from anyio>=3->litestar>=2.8.3->evidently==0.7.7) (1.3.1)
# Requirement already satisfied: httpcore==1.* in .\venv\lib\site-packages (from httpx>=0.22->litestar>=2.8.3->evidently==0.7.7) (1.0.9)
# Requirement already satisfied: h11>=0.16 in .\venv\lib\site-packages (from httpcore==1.*->httpx>=0.22->litestar>=2.8.3->evidently==0.7.7) (0.16.0)
# Requirement already satisfied: joblib in .\venv\lib\site-packages (from nltk>=3.6.7->evidently==0.7.7) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in .\venv\lib\site-packages (from nltk>=3.6.7->evidently==0.7.7) (2024.11.6)
# Requirement already satisfied: tqdm in .\venv\lib\site-packages (from nltk>=3.6.7->evidently==0.7.7) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\venv\lib\site-packages (from pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently==0.7.7) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\venv\lib\site-packages (from pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently==0.7.7) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in .\venv\lib\site-packages (from pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently==0.7.7) (2025.2)
# Requirement already satisfied: pyarrow>=10.0.1 in .\venv\lib\site-packages (from pandas[parquet]>=1.3.5->evidently==0.7.7) (20.0.0)
# Requirement already satisfied: faker>=5.0.0 in .\venv\lib\site-packages (from polyfactory>=2.6.3->litestar>=2.8.3->evidently==0.7.7) (37.4.0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\venv\lib\site-packages (from pydantic>=1.10.16->evidently==0.7.7) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in .\venv\lib\site-packages (from pydantic>=1.10.16->evidently==0.7.7) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in .\venv\lib\site-packages (from pydantic>=1.10.16->evidently==0.7.7) (0.4.1)
# Requirement already satisfied: six>=1.5 in .\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently==0.7.7) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\venv\lib\site-packages (from requests>=2.32.0->evidently==0.7.7) (3.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\venv\lib\site-packages (from rich>=13->evidently==0.7.7) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\venv\lib\site-packages (from rich>=13->evidently==0.7.7) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in .\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13->evidently==0.7.7) (0.1.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in .\venv\lib\site-packages (from scikit-learn>=1.0.1->evidently==0.7.7) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in .\venv\lib\site-packages (from statsmodels>=0.12.2->evidently==0.7.7) (1.0.1)
# Requirement already satisfied: shellingham>=1.3.0 in .\venv\lib\site-packages (from typer>=0.3->evidently==0.7.7) (1.5.4)
# Requirement already satisfied: colorama in .\venv\lib\site-packages (from click->litestar>=2.8.3->evidently==0.7.7) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in .\venv\lib\site-packages (from typing-inspect>=0.9.0->evidently==0.7.7) (1.1.0)
# Requirement already satisfied: httptools>=0.6.3 in .\venv\lib\site-packages (from uvicorn[standard]>=0.22.0->evidently==0.7.7) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in .\venv\lib\site-packages (from uvicorn[standard]>=0.22.0->evidently==0.7.7) (1.1.0)
# Requirement already satisfied: watchfiles>=0.13 in .\venv\lib\site-packages (from uvicorn[standard]>=0.22.0->evidently==0.7.7) (1.0.5)
# Requirement already satisfied: websockets>=10.4 in .\venv\lib\site-packages (from uvicorn[standard]>=0.22.0->evidently==0.7.7) (15.0.1)
# Requirement already satisfied: zipp>=3.20 in .\venv\lib\site-packages (from importlib-metadata->litestar>=2.8.3->evidently==0.7.7) (3.23.0)
# Using cached evidently-0.7.7-py3-none-any.whl (5.2 MB)
# Installing collected packages: evidently
# Successfully installed evidently-0.7.7

# %%
import evidently
print(evidently.__version__)
# Out:
# 0.7.7

# %%
import pandas as pd
from evidently import Dataset, DataDefinition, Report
from evidently.descriptors import (
    Contains,
    DoesNotContain,
    IncludesWords,
    ExcludesWords,
    ContainsLink,
    ItemMatch,
    ItemNoMatch,
    WordMatch,
    WordNoMatch
)
 
# Load dataset
df = pd.read_csv("C:\\new\\health_and_fitness_qna.csv")
 
# Ensure we have a 'Text' column for analysis (combine Question + Answer)
df["Text"] = df["Question"].fillna("") + " " + df["Answer"].fillna("")
 
# Simulate row-level item/word expectations (for demo purposes)
df["Expected_items"] = [["fitness", "diet"]] * len(df)
df["Forbidden_items"] = [["injury", "risk"]] * len(df)
df["Expected_words"] = [["exercise", "healthy"]] * len(df)
df["Forbidden_words"] = [["junk", "drugs"]] * len(df)
 
# Define text column
data_def = DataDefinition(text_columns=["Text"])
 
# Build dataset with content-check descriptors
eval_dataset = Dataset.from_pandas(
    df,
    data_definition=data_def,
    descriptors=[
        # Static list checks
        Contains(column_name="Text", items=["fitness", "health"], mode="any", case_sensitive=False, alias="has_health_keywords"),
        DoesNotContain(column_name="Text", items=["illegal", "fake"], case_sensitive=False, alias="no_illegal_terms"),
        IncludesWords(column_name="Text", words_list=["exercise", "wellness"], mode="any", lemmatize=True, alias="includes_wellness_terms"),
        ExcludesWords(column_name="Text", words_list=["scam", "spam"], alias="excludes_bad_words"),
        ContainsLink(column_name="Text", alias="has_links"),
 
        # Row-level dynamic list checks
        ItemMatch(columns=["Text", "Expected_items"], mode="all", case_sensitive=False, alias="matches_expected_items"),
        ItemNoMatch(columns=["Text", "Forbidden_items"], alias="no_forbidden_items"),
        WordMatch(columns=["Text", "Expected_words"], mode="all", lemmatize=True, alias="matches_expected_words"),
        WordNoMatch(columns=["Text", "Forbidden_words"], mode="all", lemmatize=True, alias="no_forbidden_words")
    ]
)
 
# Run the report
report = Report(metrics=[])
report.run(eval_dataset)
 
# View result DataFrame
results_df = eval_dataset.as_dataframe()
print(results_df[[
    "Text",
    "has_health_keywords",
    "no_illegal_terms",
    "includes_wellness_terms",
    "excludes_bad_words",
    "has_links",
    "matches_expected_items",
    "no_forbidden_items",
    "matches_expected_words",
    "no_forbidden_words"
]])
# Out:
#                                                  Text  has_health_keywords  \
# 0   Should I eat breakfast before or after exercis...                False
# 1   What are some healthy snacks I can eat during ...                 True
# 2   Is it okay to have coffee or tea before a work...                False
# 3   I don’t like drinking plain water. What are so...                False
# 4   Can I replace water with sports drinks during ...                False
# 5   I’m 40 and have never exercised before. Where ...                False
# 6   How many times a week should I do strength tra...                 True
# 7   How does intermittent fasting work? How do I k...                False
# 8   How do I stay motivated to work out consistent...                 True
# 9   How long should I rest between workout session...                False
# 10  Can I build muscle without going to the gym an...                False
# 11  How can I exercise at home if I can’t go to th...                False
# 12  When should I take my medication, before or af...                 True
#
#     no_illegal_terms  includes_wellness_terms  excludes_bad_words  has_links  \
# 0               True                     True                True      False
# 1               True                    False                True      False
# 2               True                    False                True      False
# 3               True                    False                True      False
# 4               True                     True                True      False
# 5               True                     True                True      False
# 6               True                     True                True      False
# 7               True                    False                True      False
# 8               True                     True                True      False
# 9               True                    False                True      False
# 10              True                     True                True      False
# 11              True                     True                True      False
# 12              True                     True                True      False
#
#     matches_expected_items  no_forbidden_items  matches_expected_words  \
# 0                    False                True                   False
# 1                    False                True                   False
# 2                    False                True                   False
# 3                    False                True                   False
# 4                    False                True                   False
# 5                    False                True                   False
# 6                    False               False                   False
# 7                    False                True                   False
# 8                    False                True                   False
# 9                    False                True                   False
# 10                   False                True                   False
# 11                   False                True                   False
# 12                   False                True                   False
#
#     no_forbidden_words
# 0                 True
# 1                 True
# 2                 True
# 3                 True
# 4                 True
# 5                 True
# 6                 True
# 7                 True
# 8                 True
# 9                 True
# 10                True
# 11                True
# 12                True

# %%
import pandas as pd
from evidently import Dataset, DataDefinition, Report
from evidently.descriptors import (
    Contains,
    DoesNotContain,
    IncludesWords,
    ExcludesWords,
    ContainsLink,
    ItemMatch,
    ItemNoMatch,
    WordMatch,
    WordNoMatch
)
 
# Load dataset
df = pd.read_csv("C:\\new\\health_and_fitness_qna.csv")
 
# Ensure we have a 'Text' column for analysis (combine Question + Answer)
df["Text"] = df["Question"].fillna("") + " " + df["Answer"].fillna("")
 
# Simulate row-level item/word expectations (for demo purposes)
df["Expected_items"] = [["fitness", "diet"]] * len(df)
df["Forbidden_items"] = [["injury", "risk"]] * len(df)
df["Expected_words"] = [["exercise", "healthy"]] * len(df)
df["Forbidden_words"] = [["junk", "drugs"]] * len(df)
 
# Define text column
data_def = DataDefinition(text_columns=["Text"])
 
# Build dataset with content-check descriptors
eval_dataset = Dataset.from_pandas(
    df,
    data_definition=data_def,
    descriptors=[
        # Static list checks
        Contains(column_name="Text", items=["fitness", "health"], mode="all", case_sensitive=False, alias="has_health_keywords"),
        DoesNotContain(column_name="Text", items=["illegal", "fake"], case_sensitive=False, alias="no_illegal_terms"),
        IncludesWords(column_name="Text", words_list=["exercise", "wellness"], mode="all", lemmatize=True, alias="includes_wellness_terms"),
        ExcludesWords(column_name="Text", words_list=["scam", "spam"], alias="excludes_bad_words"),
        ContainsLink(column_name="Text", alias="has_links"),
 
        # Row-level dynamic list checks
        ItemMatch(columns=["Text", "Expected_items"], mode="all", case_sensitive=False, alias="matches_expected_items"),
        ItemNoMatch(columns=["Text", "Forbidden_items"], alias="no_forbidden_items"),
        WordMatch(columns=["Text", "Expected_words"], mode="all", lemmatize=True, alias="matches_expected_words"),
        WordNoMatch(columns=["Text", "Forbidden_words"], mode="all", lemmatize=True, alias="no_forbidden_words")
    ]
)
 
# Run the report
report = Report(metrics=[])
report.run(eval_dataset)
 
# View result DataFrame
results_df = eval_dataset.as_dataframe()
print(results_df[[
    "Text",
    "has_health_keywords",
    "no_illegal_terms",
    "includes_wellness_terms",
    "excludes_bad_words",
    "has_links",
    "matches_expected_items",
    "no_forbidden_items",
    "matches_expected_words",
    "no_forbidden_words"
]])
# Out:
#                                                  Text  has_health_keywords  \
# 0   Should I eat breakfast before or after exercis...                False
# 1   What are some healthy snacks I can eat during ...                False
# 2   Is it okay to have coffee or tea before a work...                False
# 3   I don’t like drinking plain water. What are so...                False
# 4   Can I replace water with sports drinks during ...                False
# 5   I’m 40 and have never exercised before. Where ...                False
# 6   How many times a week should I do strength tra...                False
# 7   How does intermittent fasting work? How do I k...                False
# 8   How do I stay motivated to work out consistent...                False
# 9   How long should I rest between workout session...                False
# 10  Can I build muscle without going to the gym an...                False
# 11  How can I exercise at home if I can’t go to th...                False
# 12  When should I take my medication, before or af...                False
#
#     no_illegal_terms  includes_wellness_terms  excludes_bad_words  has_links  \
# 0               True                    False                True      False
# 1               True                    False                True      False
# 2               True                    False                True      False
# 3               True                    False                True      False
# 4               True                    False                True      False
# 5               True                    False                True      False
# 6               True                    False                True      False
# 7               True                    False                True      False
# 8               True                    False                True      False
# 9               True                    False                True      False
# 10              True                    False                True      False
# 11              True                    False                True      False
# 12              True                    False                True      False
#
#     matches_expected_items  no_forbidden_items  matches_expected_words  \
# 0                    False                True                   False
# 1                    False                True                   False
# 2                    False                True                   False
# 3                    False                True                   False
# 4                    False                True                   False
# 5                    False                True                   False
# 6                    False               False                   False
# 7                    False                True                   False
# 8                    False                True                   False
# 9                    False                True                   False
# 10                   False                True                   False
# 11                   False                True                   False
# 12                   False                True                   False
#
#     no_forbidden_words
# 0                 True
# 1                 True
# 2                 True
# 3                 True
# 4                 True
# 5                 True
# 6                 True
# 7                 True
# 8                 True
# 9                 True
# 10                True
# 11                True
# 12                True
